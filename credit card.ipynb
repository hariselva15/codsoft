# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv(r"C:\Users\ACER\Documents\archive_(3)[1]\fraudTrain.csv")
data
# Out:
#          Unnamed: 0 trans_date_trans_time        cc_num  \
# 0                 0      01-01-2019 00:00  2.700000e+15
# 1                 1      01-01-2019 00:00  6.300000e+11
# 2                 2      01-01-2019 00:00  3.890000e+13
# 3                 3      01-01-2019 00:01  3.530000e+15
# 4                 4      01-01-2019 00:03  3.760000e+14
# ...             ...                   ...           ...
# 1048570     1048570      10-03-2020 16:07  6.010000e+15
# 1048571     1048571      10-03-2020 16:07  4.840000e+15
# 1048572     1048572      10-03-2020 16:08  5.720000e+11
# 1048573     1048573      10-03-2020 16:08  4.650000e+18
# 1048574     1048574      10-03-2020 16:08  2.280000e+15
#
#                                    merchant        category     amt    zip  \
# 0                fraud_Rippin, Kub and Mann        misc_net    4.97  28654
# 1           fraud_Heller, Gutmann and Zieme     grocery_pos  107.23  99160
# 2                      fraud_Lind-Buckridge   entertainment  220.11  83252
# 3        fraud_Kutch, Hermiston and Farrell   gas_transport   45.00  59632
# 4                       fraud_Keeling-Crist        misc_pos   41.96  24433
# ...                                     ...             ...     ...    ...
# 1048570                     fraud_Fadel Inc  health_fitness   77.00  21405
# 1048571    fraud_Cremin, Hamill and Reichel        misc_pos  116.94  52563
# 1048572  fraud_O'Connell, Botsford and Hand            home   21.27  40202
# 1048573              fraud_Thompson-Gleason  health_fitness    9.52  11796
# 1048574                 fraud_Buckridge PLC        misc_pos    6.81  30009
#
#              lat      long  city_pop   unix_time  merch_lat  merch_long  \
# 0        36.0788  -81.1781      3495  1325376018  36.011293  -82.048315
# 1        48.8878 -118.2105       149  1325376044  49.159047 -118.186462
# 2        42.1808 -112.2620      4154  1325376051  43.150704 -112.154481
# 3        46.2306 -112.1138      1939  1325376076  47.034331 -112.561071
# 4        38.4207  -79.4629        99  1325376186  38.674999  -78.632459
# ...          ...       ...       ...         ...        ...         ...
# 1048570  39.0305  -76.5515     92106  1362931649  38.779464  -76.317042
# 1048571  41.1826  -92.3097      1583  1362931670  41.400318  -92.726724
# 1048572  38.2507  -85.7476    736284  1362931711  37.293339  -84.798122
# 1048573  40.7320  -73.1000      4056  1362931718  39.773077  -72.213209
# 1048574  34.0770  -84.3033    165556  1362931730  33.601468  -83.891921
#
#          is_fraud
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 1048570         0
# 1048571         0
# 1048572         0
# 1048573         0
# 1048574         0
#
# [1048575 rows x 14 columns]

# %%
data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time        cc_num  \
# 0           0      01-01-2019 00:00  2.700000e+15
# 1           1      01-01-2019 00:00  6.300000e+11
# 2           2      01-01-2019 00:00  3.890000e+13
# 3           3      01-01-2019 00:01  3.530000e+15
# 4           4      01-01-2019 00:03  3.760000e+14
#
#                              merchant       category     amt    zip      lat  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97  28654  36.0788
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  99160  48.8878
# 2                fraud_Lind-Buckridge  entertainment  220.11  83252  42.1808
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00  59632  46.2306
# 4                 fraud_Keeling-Crist       misc_pos   41.96  24433  38.4207
#
#        long  city_pop   unix_time  merch_lat  merch_long  is_fraud
# 0  -81.1781      3495  1325376018  36.011293  -82.048315         0
# 1 -118.2105       149  1325376044  49.159047 -118.186462         0
# 2 -112.2620      4154  1325376051  43.150704 -112.154481         0
# 3 -112.1138      1939  1325376076  47.034331 -112.561071         0
# 4  -79.4629        99  1325376186  38.674999  -78.632459         0

# %%
data.tail()
# Out:
#          Unnamed: 0 trans_date_trans_time        cc_num  \
# 1048570     1048570      10-03-2020 16:07  6.010000e+15
# 1048571     1048571      10-03-2020 16:07  4.840000e+15
# 1048572     1048572      10-03-2020 16:08  5.720000e+11
# 1048573     1048573      10-03-2020 16:08  4.650000e+18
# 1048574     1048574      10-03-2020 16:08  2.280000e+15
#
#                                    merchant        category     amt    zip  \
# 1048570                     fraud_Fadel Inc  health_fitness   77.00  21405
# 1048571    fraud_Cremin, Hamill and Reichel        misc_pos  116.94  52563
# 1048572  fraud_O'Connell, Botsford and Hand            home   21.27  40202
# 1048573              fraud_Thompson-Gleason  health_fitness    9.52  11796
# 1048574                 fraud_Buckridge PLC        misc_pos    6.81  30009
#
#              lat     long  city_pop   unix_time  merch_lat  merch_long  \
# 1048570  39.0305 -76.5515     92106  1362931649  38.779464  -76.317042
# 1048571  41.1826 -92.3097      1583  1362931670  41.400318  -92.726724
# 1048572  38.2507 -85.7476    736284  1362931711  37.293339  -84.798122
# 1048573  40.7320 -73.1000      4056  1362931718  39.773077  -72.213209
# 1048574  34.0770 -84.3033    165556  1362931730  33.601468  -83.891921
#
#          is_fraud
# 1048570         0
# 1048571         0
# 1048572         0
# 1048573         0
# 1048574         0

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'zip', 'lat', 'long', 'city_pop', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Unnamed: 0                 int64
# trans_date_trans_time     object
# cc_num                   float64
# merchant                  object
# category                  object
# amt                      float64
# zip                        int64
# lat                      float64
# long                     float64
# city_pop                   int64
# unix_time                  int64
# merch_lat                float64
# merch_long               float64
# is_fraud                   int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Unnamed: 0             1048575 non-null  int64
#  1   trans_date_trans_time  1048575 non-null  object
#  2   cc_num                 1048575 non-null  float64
#  3   merchant               1048575 non-null  object
#  4   category               1048575 non-null  object
#  5   amt                    1048575 non-null  float64
#  6   zip                    1048575 non-null  int64
#  7   lat                    1048575 non-null  float64
#  8   long                   1048575 non-null  float64
#  9   city_pop               1048575 non-null  int64
#  10  unix_time              1048575 non-null  int64
#  11  merch_lat              1048575 non-null  float64
#  12  merch_long             1048575 non-null  float64
#  13  is_fraud               1048575 non-null  int64
# dtypes: float64(6), int64(5), object(3)
# memory usage: 112.0+ MB

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1048575, step=1)

# %%
data.count()
# Out:
# Unnamed: 0               1048575
# trans_date_trans_time    1048575
# cc_num                   1048575
# merchant                 1048575
# category                 1048575
# amt                      1048575
# zip                      1048575
# lat                      1048575
# long                     1048575
# city_pop                 1048575
# unix_time                1048575
# merch_lat                1048575
# merch_long               1048575
# is_fraud                 1048575
# dtype: int64

# %%
data.notnull
# Out:
# <bound method DataFrame.notnull of          Unnamed: 0 trans_date_trans_time        cc_num  \
# 0                 0      01-01-2019 00:00  2.700000e+15
# 1                 1      01-01-2019 00:00  6.300000e+11
# 2                 2      01-01-2019 00:00  3.890000e+13
# 3                 3      01-01-2019 00:01  3.530000e+15
# 4                 4      01-01-2019 00:03  3.760000e+14
# ...             ...                   ...           ...
# 1048570     1048570      10-03-2020 16:07  6.010000e+15
# 1048571     1048571      10-03-2020 16:07  4.840000e+15
# 1048572     1048572      10-03-2020 16:08  5.720000e+11
# 1048573     1048573      10-03-2020 16:08  4.650000e+18
# 1048574     1048574      10-03-2020 16:08  2.280000e+15
#
#                                    merchant        category     amt    zip  \
# 0                fraud_Rippin, Kub and Mann        misc_net    4.97  28654
# 1           fraud_Heller, Gutmann and Zieme     grocery_pos  107.23  99160
# 2                      fraud_Lind-Buckridge   entertainment  220.11  83252
# 3        fraud_Kutch, Hermiston and Farrell   gas_transport   45.00  59632
# 4                       fraud_Keeling-Crist        misc_pos   41.96  24433
# ...                                     ...             ...     ...    ...
# 1048570                     fraud_Fadel Inc  health_fitness   77.00  21405
# 1048571    fraud_Cremin, Hamill and Reichel        misc_pos  116.94  52563
# 1048572  fraud_O'Connell, Botsford and Hand            home   21.27  40202
# 1048573              fraud_Thompson-Gleason  health_fitness    9.52  11796
# 1048574                 fraud_Buckridge PLC        misc_pos    6.81  30009
#
#              lat      long  city_pop   unix_time  merch_lat  merch_long  \
# 0        36.0788  -81.1781      3495  1325376018  36.011293  -82.048315
# 1        48.8878 -118.2105       149  1325376044  49.159047 -118.186462
# 2        42.1808 -112.2620      4154  1325376051  43.150704 -112.154481
# 3        46.2306 -112.1138      1939  1325376076  47.034331 -112.561071
# 4        38.4207  -79.4629        99  1325376186  38.674999  -78.632459
# ...          ...       ...       ...         ...        ...         ...
# 1048570  39.0305  -76.5515     92106  1362931649  38.779464  -76.317042
# 1048571  41.1826  -92.3097      1583  1362931670  41.400318  -92.726724
# 1048572  38.2507  -85.7476    736284  1362931711  37.293339  -84.798122
# 1048573  40.7320  -73.1000      4056  1362931718  39.773077  -72.213209
# 1048574  34.0770  -84.3033    165556  1362931730  33.601468  -83.891921
#
#          is_fraud
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 1048570         0
# 1048571         0
# 1048572         0
# 1048573         0
# 1048574         0
#
# [1048575 rows x 14 columns]>

# %%
data.notnull().sum()
# Out:
# Unnamed: 0               1048575
# trans_date_trans_time    1048575
# cc_num                   1048575
# merchant                 1048575
# category                 1048575
# amt                      1048575
# zip                      1048575
# lat                      1048575
# long                     1048575
# city_pop                 1048575
# unix_time                1048575
# merch_lat                1048575
# merch_long               1048575
# is_fraud                 1048575
# dtype: int64

# %%
data.nunique
# Out:
# <bound method DataFrame.nunique of          Unnamed: 0 trans_date_trans_time        cc_num  \
# 0                 0      01-01-2019 00:00  2.700000e+15
# 1                 1      01-01-2019 00:00  6.300000e+11
# 2                 2      01-01-2019 00:00  3.890000e+13
# 3                 3      01-01-2019 00:01  3.530000e+15
# 4                 4      01-01-2019 00:03  3.760000e+14
# ...             ...                   ...           ...
# 1048570     1048570      10-03-2020 16:07  6.010000e+15
# 1048571     1048571      10-03-2020 16:07  4.840000e+15
# 1048572     1048572      10-03-2020 16:08  5.720000e+11
# 1048573     1048573      10-03-2020 16:08  4.650000e+18
# 1048574     1048574      10-03-2020 16:08  2.280000e+15
#
#                                    merchant        category     amt    zip  \
# 0                fraud_Rippin, Kub and Mann        misc_net    4.97  28654
# 1           fraud_Heller, Gutmann and Zieme     grocery_pos  107.23  99160
# 2                      fraud_Lind-Buckridge   entertainment  220.11  83252
# 3        fraud_Kutch, Hermiston and Farrell   gas_transport   45.00  59632
# 4                       fraud_Keeling-Crist        misc_pos   41.96  24433
# ...                                     ...             ...     ...    ...
# 1048570                     fraud_Fadel Inc  health_fitness   77.00  21405
# 1048571    fraud_Cremin, Hamill and Reichel        misc_pos  116.94  52563
# 1048572  fraud_O'Connell, Botsford and Hand            home   21.27  40202
# 1048573              fraud_Thompson-Gleason  health_fitness    9.52  11796
# 1048574                 fraud_Buckridge PLC        misc_pos    6.81  30009
#
#              lat      long  city_pop   unix_time  merch_lat  merch_long  \
# 0        36.0788  -81.1781      3495  1325376018  36.011293  -82.048315
# 1        48.8878 -118.2105       149  1325376044  49.159047 -118.186462
# 2        42.1808 -112.2620      4154  1325376051  43.150704 -112.154481
# 3        46.2306 -112.1138      1939  1325376076  47.034331 -112.561071
# 4        38.4207  -79.4629        99  1325376186  38.674999  -78.632459
# ...          ...       ...       ...         ...        ...         ...
# 1048570  39.0305  -76.5515     92106  1362931649  38.779464  -76.317042
# 1048571  41.1826  -92.3097      1583  1362931670  41.400318  -92.726724
# 1048572  38.2507  -85.7476    736284  1362931711  37.293339  -84.798122
# 1048573  40.7320  -73.1000      4056  1362931718  39.773077  -72.213209
# 1048574  34.0770  -84.3033    165556  1362931730  33.601468  -83.891921
#
#          is_fraud
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 1048570         0
# 1048571         0
# 1048572         0
# 1048573         0
# 1048574         0
#
# [1048575 rows x 14 columns]>

# %%
data.head(10)
# Out:
#    Unnamed: 0 trans_date_trans_time        cc_num  \
# 0           0      01-01-2019 00:00  2.700000e+15
# 1           1      01-01-2019 00:00  6.300000e+11
# 2           2      01-01-2019 00:00  3.890000e+13
# 3           3      01-01-2019 00:01  3.530000e+15
# 4           4      01-01-2019 00:03  3.760000e+14
# 5           5      01-01-2019 00:04  4.770000e+15
# 6           6      01-01-2019 00:04  3.010000e+13
# 7           7      01-01-2019 00:05  6.010000e+15
# 8           8      01-01-2019 00:05  4.920000e+15
# 9           9      01-01-2019 00:06  2.720000e+15
#
#                              merchant       category     amt    zip      lat  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97  28654  36.0788
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  99160  48.8878
# 2                fraud_Lind-Buckridge  entertainment  220.11  83252  42.1808
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00  59632  46.2306
# 4                 fraud_Keeling-Crist       misc_pos   41.96  24433  38.4207
# 5    fraud_Stroman, Hudson and Erdman  gas_transport   94.63  18917  40.3750
# 6               fraud_Rowe-Vandervort    grocery_net   44.54  67851  37.9931
# 7                fraud_Corwin-Collins  gas_transport   71.65  22824  38.8432
# 8                    fraud_Herzog Ltd       misc_pos    4.27  15665  40.3359
# 9   fraud_Schoen, Kuphal and Nitzsche    grocery_pos  198.39  37040  36.5220
#
#        long  city_pop   unix_time  merch_lat  merch_long  is_fraud
# 0  -81.1781      3495  1325376018  36.011293  -82.048315         0
# 1 -118.2105       149  1325376044  49.159047 -118.186462         0
# 2 -112.2620      4154  1325376051  43.150704 -112.154481         0
# 3 -112.1138      1939  1325376076  47.034331 -112.561071         0
# 4  -79.4629        99  1325376186  38.674999  -78.632459         0
# 5  -75.2045      2158  1325376248  40.653382  -76.152667         0
# 6 -100.9893      2691  1325376282  37.162705 -100.153370         0
# 7  -78.6003      6018  1325376308  38.948089  -78.540296         0
# 8  -79.6607      1472  1325376318  40.351813  -79.958146         0
# 9  -87.3490    151785  1325376361  37.179198  -87.485381         0

# %%
data=data.drop('trans_date_trans_time',axis=1)
data
# Out:
#          Unnamed: 0        cc_num                            merchant  \
# 0                 0  2.700000e+15          fraud_Rippin, Kub and Mann
# 1                 1  6.300000e+11     fraud_Heller, Gutmann and Zieme
# 2                 2  3.890000e+13                fraud_Lind-Buckridge
# 3                 3  3.530000e+15  fraud_Kutch, Hermiston and Farrell
# 4                 4  3.760000e+14                 fraud_Keeling-Crist
# ...             ...           ...                                 ...
# 1048570     1048570  6.010000e+15                     fraud_Fadel Inc
# 1048571     1048571  4.840000e+15    fraud_Cremin, Hamill and Reichel
# 1048572     1048572  5.720000e+11  fraud_O'Connell, Botsford and Hand
# 1048573     1048573  4.650000e+18              fraud_Thompson-Gleason
# 1048574     1048574  2.280000e+15                 fraud_Buckridge PLC
#
#                category     amt    zip      lat      long  city_pop  \
# 0              misc_net    4.97  28654  36.0788  -81.1781      3495
# 1           grocery_pos  107.23  99160  48.8878 -118.2105       149
# 2         entertainment  220.11  83252  42.1808 -112.2620      4154
# 3         gas_transport   45.00  59632  46.2306 -112.1138      1939
# 4              misc_pos   41.96  24433  38.4207  -79.4629        99
# ...                 ...     ...    ...      ...       ...       ...
# 1048570  health_fitness   77.00  21405  39.0305  -76.5515     92106
# 1048571        misc_pos  116.94  52563  41.1826  -92.3097      1583
# 1048572            home   21.27  40202  38.2507  -85.7476    736284
# 1048573  health_fitness    9.52  11796  40.7320  -73.1000      4056
# 1048574        misc_pos    6.81  30009  34.0770  -84.3033    165556
#
#           unix_time  merch_lat  merch_long  is_fraud
# 0        1325376018  36.011293  -82.048315         0
# 1        1325376044  49.159047 -118.186462         0
# 2        1325376051  43.150704 -112.154481         0
# 3        1325376076  47.034331 -112.561071         0
# 4        1325376186  38.674999  -78.632459         0
# ...             ...        ...         ...       ...
# 1048570  1362931649  38.779464  -76.317042         0
# 1048571  1362931670  41.400318  -92.726724         0
# 1048572  1362931711  37.293339  -84.798122         0
# 1048573  1362931718  39.773077  -72.213209         0
# 1048574  1362931730  33.601468  -83.891921         0
#
# [1048575 rows x 13 columns]

# %%
data=data.drop('merchant',axis=1)
data
# Out:
#          Unnamed: 0        cc_num        category     amt    zip      lat  \
# 0                 0  2.700000e+15        misc_net    4.97  28654  36.0788
# 1                 1  6.300000e+11     grocery_pos  107.23  99160  48.8878
# 2                 2  3.890000e+13   entertainment  220.11  83252  42.1808
# 3                 3  3.530000e+15   gas_transport   45.00  59632  46.2306
# 4                 4  3.760000e+14        misc_pos   41.96  24433  38.4207
# ...             ...           ...             ...     ...    ...      ...
# 1048570     1048570  6.010000e+15  health_fitness   77.00  21405  39.0305
# 1048571     1048571  4.840000e+15        misc_pos  116.94  52563  41.1826
# 1048572     1048572  5.720000e+11            home   21.27  40202  38.2507
# 1048573     1048573  4.650000e+18  health_fitness    9.52  11796  40.7320
# 1048574     1048574  2.280000e+15        misc_pos    6.81  30009  34.0770
#
#              long  city_pop   unix_time  merch_lat  merch_long  is_fraud
# 0        -81.1781      3495  1325376018  36.011293  -82.048315         0
# 1       -118.2105       149  1325376044  49.159047 -118.186462         0
# 2       -112.2620      4154  1325376051  43.150704 -112.154481         0
# 3       -112.1138      1939  1325376076  47.034331 -112.561071         0
# 4        -79.4629        99  1325376186  38.674999  -78.632459         0
# ...           ...       ...         ...        ...         ...       ...
# 1048570  -76.5515     92106  1362931649  38.779464  -76.317042         0
# 1048571  -92.3097      1583  1362931670  41.400318  -92.726724         0
# 1048572  -85.7476    736284  1362931711  37.293339  -84.798122         0
# 1048573  -73.1000      4056  1362931718  39.773077  -72.213209         0
# 1048574  -84.3033    165556  1362931730  33.601468  -83.891921         0
#
# [1048575 rows x 12 columns]

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# cc_num        0
# category      0
# amt           0
# zip           0
# lat           0
# long          0
# city_pop      0
# unix_time     0
# merch_lat     0
# merch_long    0
# is_fraud      0
# dtype: int64

# %%
data['is_fraud'].value_counts()
# Out:
# is_fraud
# 0    1042569
# 1       6006
# Name: count, dtype: int64

# %%
data=data.drop('category',axis=1)
data
# Out:
#          Unnamed: 0        cc_num     amt    zip      lat      long  city_pop  \
# 0                 0  2.700000e+15    4.97  28654  36.0788  -81.1781      3495
# 1                 1  6.300000e+11  107.23  99160  48.8878 -118.2105       149
# 2                 2  3.890000e+13  220.11  83252  42.1808 -112.2620      4154
# 3                 3  3.530000e+15   45.00  59632  46.2306 -112.1138      1939
# 4                 4  3.760000e+14   41.96  24433  38.4207  -79.4629        99
# ...             ...           ...     ...    ...      ...       ...       ...
# 1048570     1048570  6.010000e+15   77.00  21405  39.0305  -76.5515     92106
# 1048571     1048571  4.840000e+15  116.94  52563  41.1826  -92.3097      1583
# 1048572     1048572  5.720000e+11   21.27  40202  38.2507  -85.7476    736284
# 1048573     1048573  4.650000e+18    9.52  11796  40.7320  -73.1000      4056
# 1048574     1048574  2.280000e+15    6.81  30009  34.0770  -84.3033    165556
#
#           unix_time  merch_lat  merch_long  is_fraud
# 0        1325376018  36.011293  -82.048315         0
# 1        1325376044  49.159047 -118.186462         0
# 2        1325376051  43.150704 -112.154481         0
# 3        1325376076  47.034331 -112.561071         0
# 4        1325376186  38.674999  -78.632459         0
# ...             ...        ...         ...       ...
# 1048570  1362931649  38.779464  -76.317042         0
# 1048571  1362931670  41.400318  -92.726724         0
# 1048572  1362931711  37.293339  -84.798122         0
# 1048573  1362931718  39.773077  -72.213209         0
# 1048574  1362931730  33.601468  -83.891921         0
#
# [1048575 rows x 11 columns]

# %%
legit = data[data.is_fraud == 0]
fraud = data[data.is_fraud == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (1042569, 11)
# (6006, 11)

# %%
legit.merch_long.describe()
# Out:
# count    1.042569e+06
# mean    -9.022863e+01
# std      1.376795e+01
# min     -1.666712e+02
# 25%     -9.690072e+01
# 50%     -8.744176e+01
# 75%     -8.023372e+01
# max     -6.695090e+01
# Name: merch_long, dtype: float64

# %%
fraud.merch_long.describe()
# Out:
# count    6006.000000
# mean      -89.853555
# std        14.275310
# min      -166.550779
# 25%       -96.387018
# 50%       -86.918340
# 75%       -79.953243
# max       -67.569238
# Name: merch_long, dtype: float64

# %%
legit_sample = legit.sample(n=85)
legit_sample
# Out:
#         Unnamed: 0        cc_num     amt    zip      lat      long  city_pop  \
# 389051      389051  3.520000e+15   94.66  32960  27.6330  -80.4031    105638
# 5117          5117  4.770000e+18    6.00  17058  40.5553  -77.4001      1909
# 723545      723545  5.020000e+11   53.42   6444  41.7918  -72.7188       370
# 982091      982091  5.100000e+15   77.76  11978  40.8295  -72.6473      3255
# 863447      863447  3.580000e+15  121.46  73564  34.8470  -98.9836       551
# ...            ...           ...     ...    ...      ...       ...       ...
# 546855      546855  5.040000e+11   19.51  78248  29.5894  -98.5201   1595797
# 280624      280624  3.590000e+15   31.02  13484  42.8546  -75.6605       176
# 330211      330211  6.010000e+15   72.79  99323  46.1966 -118.9017      3684
# 535719      535719  4.300000e+15    1.42  49440  43.2326  -86.2492    128715
# 528086      528086  4.460000e+18   60.59  95629  38.5234 -120.6763       832
#
#          unix_time  merch_lat  merch_long  is_fraud
# 389051  1340799110  27.937740  -79.959061         0
# 5117    1325662957  39.988270  -77.756353         0
# 723545  1352057206  41.570354  -72.577663         0
# 982091  1359877081  41.038604  -72.753805         0
# 863447  1355826424  34.394766  -99.303605         0
# ...            ...        ...         ...       ...
# 546855  1345630663  29.275905  -98.654323         0
# 280624  1337379291  42.854980  -75.736867         0
# 330211  1338994017  46.760212 -118.520647         0
# 535719  1345282981  42.772061  -86.422270         0
# 528086  1345054090  38.776209 -121.351249         0
#
# [85 rows x 11 columns]

# %%
new_dataset = pd.concat([legit_sample,fraud],axis=0)
new_dataset.head()
# Out:
#         Unnamed: 0        cc_num     amt    zip      lat     long  city_pop  \
# 389051      389051  3.520000e+15   94.66  32960  27.6330 -80.4031    105638
# 5117          5117  4.770000e+18    6.00  17058  40.5553 -77.4001      1909
# 723545      723545  5.020000e+11   53.42   6444  41.7918 -72.7188       370
# 982091      982091  5.100000e+15   77.76  11978  40.8295 -72.6473      3255
# 863447      863447  3.580000e+15  121.46  73564  34.8470 -98.9836       551
#
#          unix_time  merch_lat  merch_long  is_fraud
# 389051  1340799110  27.937740  -79.959061         0
# 5117    1325662957  39.988270  -77.756353         0
# 723545  1352057206  41.570354  -72.577663         0
# 982091  1359877081  41.038604  -72.753805         0
# 863447  1355826424  34.394766  -99.303605         0

# %%
new_dataset.tail()
# Out:
#          Unnamed: 0        cc_num     amt    zip      lat     long  city_pop  \
# 1047089     1047089  3.590000e+15  690.49  57374  43.7557 -97.5936       343
# 1047157     1047157  3.550000e+15  324.74  76008  32.7004 -97.6039     13602
# 1047208     1047208  3.590000e+15  331.33  57374  43.7557 -97.5936       343
# 1047521     1047521  3.590000e+15  356.20  57374  43.7557 -97.5936       343
# 1047918     1047918  3.590000e+15  249.56  57374  43.7557 -97.5936       343
#
#           unix_time  merch_lat  merch_long  is_fraud
# 1047089  1362887989  43.254214  -98.267759         1
# 1047157  1362889904  33.607221  -97.996506         1
# 1047208  1362891561  44.228731  -98.330520         1
# 1047521  1362903771  43.988931  -97.989985         1
# 1047918  1362917373  42.868322  -98.537668         1

# %%
new_dataset['is_fraud'].value_counts()
# Out:
# is_fraud
# 1    6006
# 0      85
# Name: count, dtype: int64

# %%
#new_dataset.groupby('is_fraud').mean()

# %%
x = new_dataset.drop(columns='is_fraud',axis=1)
y = new_dataset['is_fraud']

# %%
print(x)
# Out:
#          Unnamed: 0        cc_num     amt    zip      lat     long  city_pop  \
# 389051       389051  3.520000e+15   94.66  32960  27.6330 -80.4031    105638
# 5117           5117  4.770000e+18    6.00  17058  40.5553 -77.4001      1909
# 723545       723545  5.020000e+11   53.42   6444  41.7918 -72.7188       370
# 982091       982091  5.100000e+15   77.76  11978  40.8295 -72.6473      3255
# 863447       863447  3.580000e+15  121.46  73564  34.8470 -98.9836       551
# ...             ...           ...     ...    ...      ...      ...       ...
# 1047089     1047089  3.590000e+15  690.49  57374  43.7557 -97.5936       343
# 1047157     1047157  3.550000e+15  324.74  76008  32.7004 -97.6039     13602
# 1047208     1047208  3.590000e+15  331.33  57374  43.7557 -97.5936       343
# 1047521     1047521  3.590000e+15  356.20  57374  43.7557 -97.5936       343
# 1047918     1047918  3.590000e+15  249.56  57374  43.7557 -97.5936       343
#
#           unix_time  merch_lat  merch_long
# 389051   1340799110  27.937740  -79.959061
# 5117     1325662957  39.988270  -77.756353
# 723545   1352057206  41.570354  -72.577663
# 982091   1359877081  41.038604  -72.753805
# 863447   1355826424  34.394766  -99.303605
# ...             ...        ...         ...
# 1047089  1362887989  43.254214  -98.267759
# 1047157  1362889904  33.607221  -97.996506
# 1047208  1362891561  44.228731  -98.330520
# 1047521  1362903771  43.988931  -97.989985
# 1047918  1362917373  42.868322  -98.537668
#
# [6091 rows x 10 columns]

# %%
print(y)
# Out:
# 389051     0
# 5117       0
# 723545     0
# 982091     0
# 863447     0
#           ..
# 1047089    1
# 1047157    1
# 1047208    1
# 1047521    1
# 1047918    1
# Name: is_fraud, Length: 6091, dtype: int64

# %%
x_train,x_test ,y_train,y_test=train_test_split(x , y , test_size=0.2, stratify=y, random_state=2)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (6091, 10) (4872, 10) (1219, 10)

# %%
# logistic regression
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction,  y_train)

# %%
print("accuracy_on_training_data: ",training_data_accuracy)
# Out:
# accuracy_on_training_data:  0.9860426929392446

# %%
x_test_prediction = model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction,y_test)

# %%
print('accracy score on test data :',test_data_accuracy)
# Out:
# accracy score on test data : 0.9860541427399507

# %%
import joblib

# %%
filename = 'finalized_model.save'
joblib.dump(model, filename)
# Out:
# ['finalized_model.save']

# %%
loaded_model = joblib.load(filename)
result = loaded_model.score(x_test, y_test)
print(result)
# Out:
# 0.9860541427399507
